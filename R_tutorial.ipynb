# %% [markdown]
# <a href="https://colab.research.google.com/github/masayuki054/RforS/blob/main/R_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
curve(dnorm(x), xlim=c(-2,2),ylim=c(-1, 1))
curve(x*dnorm(x), add=TRUE, col="blue"); curve(x*1,col="blue",add=TRUE)
curve(x^2*dnorm(x), add=TRUE,col="green"); curve(x^2, col="green", add=TRUE)
# Out:
# plot without title
